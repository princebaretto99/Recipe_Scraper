# %%
import pandas as pd
import numpy as np

data = pd.read_csv("./final_working_csv_1000.csv")
# data.reset_index(drop=True,inplace=True)
data = data.iloc[:,1:]

# %%
recipe = data[["title","calories","carbohydrtes_g","sodium_mg","fat_g","protiens_g","cholestrol_g","tag"]]

# %%
import random
arr = []
for _ in range(len(recipe)):
    arr.append(random.randint(0,5))

# %%
recipe['average_rating'] = arr
# Out:
# C:\Users\Princeton\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
recipe['calories'] = pd.to_numeric(recipe['calories'])
recipe['calories'] = pd.cut(recipe['calories'], bins=25)

recipe['carbohydrtes_g'] = pd.to_numeric(recipe['carbohydrtes_g'])
recipe['carbohydrtes_g'] = pd.cut(recipe['carbohydrtes_g'], bins=25)

recipe['sodium_mg'] = pd.to_numeric(recipe['sodium_mg'])
recipe['sodium_mg'] = pd.cut(recipe['sodium_mg'], bins=25)

recipe['fat_g'] = pd.to_numeric(recipe['fat_g'])
recipe['fat_g'] = pd.cut(recipe['fat_g'], bins=25)

recipe['protiens_g'] = pd.to_numeric(recipe['protiens_g'])
recipe['protiens_g'] = pd.cut(recipe['protiens_g'], bins=25)

recipe['cholestrol_g'] = pd.to_numeric(recipe['cholestrol_g'])
recipe['cholestrol_g'] = pd.cut(recipe['cholestrol_g'], bins=25)

recipe['average_rating'] = recipe['average_rating'].apply(lambda x: round(x*2)/2)
# Out:
# C:\Users\Princeton\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Princeton\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Princeton\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
recipe['tag'] = label_encoder.fit_transform(recipe['tag'])
# Out:
# C:\Users\Princeton\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
encoded = {"Breakfast" : 0, "Lunch" : 1 , "Dinner" : 2}

# %%
recipe.head(2)
# Out:
#                                           title          calories  \
# 0               Simple Roasted Butternut Squash  (-2.707, 190.28]
# 1  Simple Crustless Spinach and Mushroom Quiche  (378.56, 566.84]
#
#     carbohydrtes_g           sodium_mg             fat_g        protiens_g  \
# 0  (28.352, 35.44]  (-21.999, 884.072]  (-0.384, 15.356]  (-0.273, 10.928]
# 1  (7.088, 14.176]  (-21.999, 884.072]  (30.712, 46.068]  (10.928, 21.856]
#
#         cholestrol_g  tag  average_rating
# 0    (-0.98, 39.192]    0             0.0
# 1  (195.96, 235.152]    0             4.0

# %%
recipe_ids = [987,876,765,654,543,1234,2345,3456,4567,7890,12345,23456,34567,45678,56789,67890]

# %%
recipe = recipe.iloc[:16,:]

# %%
recipe["recipe_id"] = recipe_ids

# %%
interactions = pd.DataFrame()

# %%
interactions["user_id"] = []
interactions["recipe_id"] = []
interactions["ratings"] = []
interactions["isCook"] = []

# %%
interactions.to_csv('./interactions.csv')

# %%
interactions =  pd.read_csv("./interactions.csv")

# %%
interactions.groupby(['ratings', 'isCook']).size().reset_index().pivot(columns='ratings', index='isCook', values=0)
# Out:
# ratings     0    1    2     3    4    5
# isCook
# 0        12.0  NaN  NaN   NaN  NaN  NaN
# 1         1.0  7.0  6.0  11.0  6.0  9.0

# %%
item_dict ={}
df = recipe[['recipe_id', 'title']].sort_values('recipe_id').reset_index()

# %%
for i in range(df.shape[0]):
    item_dict[(df.loc[i,'recipe_id'])] = df.loc[i,'title']

# %%
recipes_metadata_selected_transformed = pd.get_dummies(recipe, columns = ['average_rating', 'calories',  'carbohydrtes_g','sodium_mg','fat_g','protiens_g','cholestrol_g','tag'])

# %%
recipes_metadata_selected_transformed = recipes_metadata_selected_transformed.sort_values('recipe_id').reset_index().drop('index', axis=1)

# %%
recipes_metadata_selected_transformed.head(5)
# Out:
#                                           title  recipe_id  \
# 0                              Fajita Seasoning        543
# 1               German Hamburgers (Frikadellen)        654
# 2            Creamy Italian Slow Cooker Chicken        765
# 3  Simple Crustless Spinach and Mushroom Quiche        876
# 4               Simple Roasted Butternut Squash        987
#
#    average_rating_0.0  average_rating_1.0  average_rating_2.0  \
# 0                   0                   1                   0
# 1                   0                   1                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   1                   0                   0
#
#    average_rating_3.0  average_rating_4.0  average_rating_5.0  \
# 0                   0                   0                   0
# 1                   0                   0                   0
# ...

# %%
recipes_metadata_selected_transformed.drop(['title'],inplace= True,axis=1)

# %%
from scipy.sparse import csr_matrix
recipe_metadata_csr = csr_matrix(recipes_metadata_selected_transformed.drop('recipe_id', axis=1).values)

# %%
user_recipe_interaction = pd.pivot_table(interactions, index='user_id', columns='recipe_id', values='ratings')

# %%
user_recipe_interaction = user_recipe_interaction.fillna(0)

# %%
user_id = list(user_recipe_interaction.index)
user_dict = {}
counter = 0 
for i in user_id:
    user_dict[i] = counter
    counter += 1

# %%
user_recipe_interaction_csr = csr_matrix(user_recipe_interaction.values)
user_recipe_interaction_csr
# Out:
# <22x16 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39 stored elements in Compressed Sparse Row format>

# %%
from lightfm.cross_validation import random_train_test_split
from lightfm.evaluation import auc_score, precision_at_k, recall_at_k
from lightfm import LightFM
from skopt import forest_minimize
# Out:
# C:\Users\Princeton\Anaconda3\lib\site-packages\lightfm\_lightfm_fast.py:10: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   "LightFM was compiled without OpenMP support. "

# %%
model = LightFM(loss='warp',
                random_state=2016,
                learning_rate=0.90,
                no_components=150,
                user_alpha=0.000005)

# %%
model = model.fit(user_recipe_interaction_csr,
                  epochs=100,
                  num_threads=16, verbose=False)

# %%
def sample_recommendation_user(model, interactions, user_id, user_dict, 
                               item_dict,threshold = 0,nrec_items = 5, show = True):
    
    n_users, n_items = interactions.shape
    print(n_users,n_items)
    user_x = user_dict[user_id]
    scores = pd.Series(model.predict(user_x,np.arange(n_items), item_features=recipe_metadata_csr))
    scores.index = interactions.columns
    scores = list(pd.Series(scores.sort_values(ascending=False).index))
    
    known_items = list(pd.Series(interactions.loc[user_id,:] \
                                 [interactions.loc[user_id,:] > threshold].index).sort_values(ascending=False))
    
    scores = [x for x in scores if x not in known_items]
    return_score_list = scores[0:nrec_items]
    known_items = list(pd.Series(known_items).apply(lambda x: item_dict[x]))
    scores = list(pd.Series(return_score_list).apply(lambda x: item_dict[x]))
    if show == True:
        print ("User: " + str(user_id))
        print("Known Likes:")
        counter = 1
        for i in known_items:
            print(str(counter) + '- ' + i)
            counter+=1

        print("\n Recommended Items:")
        counter = 1
        for i in scores:
            print(str(counter) + '- ' + i)
            counter+=1

# %%
sample_recommendation_user(model, user_recipe_interaction, 123, user_dict, item_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-d4a1ab655087> in <module>
# ----> 1 sample_recommendation_user(model, user_recipe_interaction, 123, user_dict, item_dict)
#
# <ipython-input-28-7edbfa4b4da2> in sample_recommendation_user(model, interactions, user_id, user_dict, item_dict, threshold, nrec_items, show)
#       4     n_users, n_items = interactions.shape
#       5     user_x = user_dict[user_id]
# ----> 6     scores = pd.Series(model.predict(user_x,np.arange(n_items), item_features=recipe_metadata_csr))
#       7     scores.index = interactions.columns
#       8     scores = list(pd.Series(scores.sort_values(ascending=False).index))
#
# ~\Anaconda3\lib\site-packages\lightfm\lightfm.py in predict(self, user_ids, item_ids, item_features, user_features, num_threads)
#     816
# ...

# %%
interactions
# Out:
#     user_id  recipe_id  ratings  isCook
# 0       123        987        3       1
# 1       123        876        4       1
# 2       123        765        3       1
# 3       123        654        2       1
# 4       123        543        1       1
# 5       234        987        5       1
# 6       234        876        2       1
# 7       234        765        3       1
# 8       234        654        1       1
# 9       234        543        5       1
# 10      123       1234        5       1
# 11      123       2345        2       1
# 12      123       3456        3       1
# 13      123       4567        1       1
# 14      123       7890        1       1
# 15      234       1234        0       1
# 16      234       2345        1       1
# 17      234       3456        3       1
# 18      234       4567        5       1
# 19      234       7890        4       1
# 20      123      12345        0       0
# 21      123      23456        0       0
# ...
